# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df = sns.load_dataset("mpg")
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
df["origin"].unique()
# Out:
# array(['usa', 'japan', 'europe'], dtype=object)

# %%
from sklearn.preprocessing import OneHotEncoder


ob1= OneHotEncoder()

encoded_data = ob1.fit_transform(df[["origin"]])
df1= pd.DataFrame(encoded_data.toarray(), columns=ob1.get_feature_names_out())

final_encoded= pd.concat([df,df1],axis=1)
print(final_encoded)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name  origin_europe  \
# 0            70     usa  chevrolet chevelle malibu            0.0
# ...

# %%
final_encoded.drop("origin",axis=1,inplace=True)

# %%
#DATA ENCODING BY LEBEL ENCODER

from sklearn.preprocessing import LabelEncoder

lebel= LabelEncoder()
df["encoded_origin"]=lebel.fit_transform(df[["origin"]])
print(df)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name  encoded_origin
# 0            70     usa  chevrolet chevelle malibu               2
# ...

# %%
from sklearn.model_selection import train_test_split

x= df.iloc[:,:-1]
y= df["encoded_origin"]
x_train,x_test,y_train, y_test= train_test_split(x,y, test_size=0.2,random_state=1)
print(x_train,x_test,y_train, y_test)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 298  23.0          8         350.0       125.0    3900          17.4
# 13   14.0          8         455.0       225.0    3086          10.0
# 376  37.0          4          91.0        68.0    2025          18.2
# 61   21.0          4         122.0        86.0    2226          16.5
# 346  32.3          4          97.0        67.0    2065          17.8
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 255  25.1          4         140.0        88.0    2720          15.4
# 72   15.0          8         304.0       150.0    3892          12.5
# 235  26.0          4          97.0        75.0    2265          18.2
# 37   18.0          6         232.0       100.0    3288          15.5
#
#      model_year origin                     name
# 298          79    usa        cadillac eldorado
# ...

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso

las= Lasso()
param_grid={"alpha":[0.1,0.001,0.5, 0.3,0.22]}
grid_search= GridSearchCV(estimator=las,param_grid=param_grid,scoring="r2", cv=5,verbose=2)

# %%
grid_search.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ..........................................alpha=0.5; total time=   0.0s
# ...
